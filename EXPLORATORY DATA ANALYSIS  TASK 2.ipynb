# %%
import pandas as pd

import matplotlib
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg' # use to give higher quality plot 
import matplotlib.pyplot as plt
plt.style.use('ggplot')

import seaborn as sns

# %%
df = pd.read_csv('data_processed.csv', index_col=0)

# %%
df.head()
# Out:
#   Channel Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicatessen
# 0  Retail  Other  12669  9656     7561     214              2674          1338
# 1  Retail  Other   7057  9810     9568    1762              3293          1776
# 2  Retail  Other   6353  8808     7684    2405              3516          7844
# 3  HoReCa  Other  13265  1196     4221    6404               507          1788
# 4  Retail  Other  22615  5410     7198    3915              1777          5185

# %%
df['Region'].value_counts()
# Out:
# Other     316
# Lisbon     77
# Porto      47
# Name: Region, dtype: int64

# %%
df['Channel'].value_counts()
# Out:
# HoReCa    298
# Retail    142
# Name: Channel, dtype: int64

# %%
df.columns.to_list()
# Out:
# ['Channel',
#  'Region',
#  'Fresh',
#  'Milk',
#  'Grocery',
#  'Frozen',
#  'Detergents_Paper',
#  'Delicatessen']

# %%
features = [
    'Channel',
    'Region',
    'Fresh',
    'Milk',
    'Grocery',
    'Frozen',
    'Detergents_Paper',
    'Delicatessen'
]

# %%
fig, axes = plt.subplots(2, 4, figsize=(7,4))
# because acces is gonna be two dimensional like 2D ARRAY  SO WE DO USE RAVEL : to make multiple PLOT IN SINGLE big FIGURE

for feature, ax in zip(features,axes.ravel()):# ravel : to make plo
    if (feature=='Channel') | (feature=='Region'):
        df[feature].value_counts().plot.bar(ax=ax)
    else:
        ax.hist(df[feature],bins= 100)
    ax.set_title(feature)
plt.tight_layout()  # this just helps to keeps things nice and prevents overlapping and unnecessary space at the same time

# %%
pplot =sns.pairplot(df, vars= features[2:])
pplot.fig.set_size_inches(7,7)
